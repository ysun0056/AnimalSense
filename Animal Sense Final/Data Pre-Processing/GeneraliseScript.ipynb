# %% [markdown]
# # Victoria Dataset : Mammals
# * Data retrival is not based on unique feature : recordID can be deleted, Using Scientific name,
# * Selective feture selection

# %%
import pandas as pa
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # preprocess function

# %%
def process(inputFile,outputFile):
    inputPath="States/"
    outPath="CleanStates/"
    path=inputPath+inputFile+".csv"
    data=pa.read_csv(path)
    print(inputFile+str(data.shape))
    metadata=open(inputFile+'.txt','w+')
    metadata.write("Shape:"+str(data.shape))
    metadata.write(str(data.columns))
    data=data[['Vernacular name - original','Scientific Name','Taxon Rank','Kingdom','Phylum','Class',
              'Family','Genus','Latitude','Longitude','Country - parsed','State - parsed','Year','Individual count']]
    metadata.write("Shape selected Columns:"+str(data.shape))
    data.dropna(inplace=True)
    data.reset_index(drop=True, inplace=True)
    metadata.write("Shape after NA:"+str(data.shape))
    data[['Year','Individual count']]=data[['Year','Individual count']].astype(int)
    data=data.sort_values(['Year','Scientific Name'],ascending=False)
    data.to_csv(outPath+outputFile+'.csv', sep=',', encoding='utf-8', index = False)

# %%
vicData=pa.read_csv('States/VIC.csv')
vicData.shape
# Out:
# (9525, 57)

# %%
vicData.head()
# Out:
#                               Record ID Catalogue Number  \
# 0  fe9f296d-13d7-49bd-ac21-bd047f85d2e4       4331716.00
# 1  fe6c0262-a2ba-4d9f-b793-4c37a2ca94bd       4247724.00
# 2  fbabe0d0-5589-4ba4-8b96-8ae69e141f5e       4199224.00
# 3  f7024420-85c3-417d-8549-5096b854612a       4207705.00
# 4  f3f54d62-8bdb-492a-8b9e-bf32e09ae149       4328492.00
#
#                                   Taxon Concept GUID  \
# 0  urn:lsid:biodiversity.org.au:afd.taxon:76cb4b8...
# 1  urn:lsid:biodiversity.org.au:afd.taxon:7a7a281...
# 2  urn:lsid:biodiversity.org.au:afd.taxon:228103e...
# 3  urn:lsid:biodiversity.org.au:afd.taxon:76cb4b8...
# 4  urn:lsid:biodiversity.org.au:afd.taxon:1b653e0...
#
#          Scientific Name - original Vernacular name - original  \
# 0  Potorous tridactylus tridactylus         Long-nosed Potoroo
# 1             Petrogale penicillata  Brush-tailed Rock-wallaby
# 2            Arctocephalus forsteri       New Zealand Fur Seal
# ...

# %%
vicData.describe()
# Out:
#        Latitude - original  Longitude - original     Latitude    Longitude  \
# count          9511.000000           9511.000000  9512.000000  9512.000000
# mean            -38.095521            143.985680   -38.095476   143.985967
# std               0.723076              2.420982     0.723004     2.420758
# min             -39.187900            140.984100   -39.188000   140.984100
# 25%             -38.417000            142.517000   -38.417000   142.517000
# 50%             -38.405000            142.519500   -38.405000   142.519500
# 75%             -38.069600            145.464100   -38.069600   145.464100
# max             -34.397600            150.009500   -34.397600   150.009500
#
#        Coordinate Precision  Coordinate Uncertainty in Metres  \
# count                   0.0                       9164.000000
# mean                    NaN                        546.050109
# std                     NaN                       2367.090798
# ...

# %%
vicData.columns
# Out:
# Index(['Record ID', 'Catalogue Number', 'Taxon Concept GUID',
#        'Scientific Name - original', 'Vernacular name - original',
#        'Scientific Name', 'Taxon Rank', 'Vernacular name', 'Kingdom', 'Phylum',
#        'Class', 'Order', 'Family', 'Genus', 'Species', 'Subspecies',
#        'Data Resource ID', 'Data Resource Name', 'Institution ID',
#        'Institution', 'Collection ID', 'Collection', 'Licence',
#        'Institution Code', 'Collection Code', 'Locality',
#        'Latitude - original', 'Longitude - original',
#        'Geodetic datum - original', 'Latitude', 'Longitude',
#        'Coordinate Precision', 'Coordinate Uncertainty in Metres',
#        'Country - parsed', 'State - parsed', 'Local Government Areas 2011',
#        'IMCRA 4 Regions', 'IBRA 7 Regions', 'Minimum elevation in meters',
#        'Maximum elevation in meters', 'Minimum depth in meters',
#        'Maximum depth in meters', 'Individual count', 'Collector', 'Year',
# ...

# %%
vicData.isnull().sum()
# Out:
# Record ID                              0
# Catalogue Number                      29
# Taxon Concept GUID                     0
# Scientific Name - original             9
# Vernacular name - original           226
# Scientific Name                        0
# Taxon Rank                             0
# Vernacular name                     1580
# Kingdom                                0
# Phylum                                 0
# Class                                  0
# Order                                  0
# Family                                 0
# Genus                                  0
# Species                               23
# Subspecies                          7968
# Data Resource ID                       0
# Data Resource Name                     0
# Institution ID                      9191
# Institution                         9191
# Collection ID                       9191
# Collection                          9191
# Licence                                0
# ...

# %% [markdown]
# ## Drop unwanted Columns:
# For duplicate columns, took the least number of `Nulls`

# %%
cleanData=vicData[['Vernacular name - original','Scientific Name','Taxon Rank','Kingdom','Phylum','Class',
              'Family','Genus','Latitude','Longitude','Country - parsed','State - parsed','Year','Individual count']]
cleanData.shape
# Out:
# (9525, 14)

# %%
cleanData.dropna(inplace=True)
cleanData.reset_index(drop=True, inplace=True)
cleanData.isnull().sum()
# Out:
# /Users/root1/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Vernacular name - original    0
# Scientific Name               0
# Taxon Rank                    0
# Kingdom                       0
# Phylum                        0
# Class                         0
# Family                        0
# Genus                         0
# Latitude                      0
# Longitude                     0
# Country - parsed              0
# State - parsed                0
# Year                          0
# Individual count              0
# dtype: int64

# %%
cleanData.shape
# Out:
# (8590, 14)

# %%
cleanData['Vernacular name - original'].value_counts()
# Out:
# Southern Right Whale         5604
# Long-nosed Potoroo           1033
# Squirrel Glider               606
# New Holland Mouse             512
# Humpback Whale                480
# Brush-tailed Rock-wallaby     144
# Common Dunnart                126
# New Zealand Fur Seal           36
# Brush-tailed Rock Wallaby      24
# Australasian Fur Seal           8
# long-eared bat                  8
# Humpback whale                  4
# Southern right whale            4
# humpback whale                  1
# Name: Vernacular name - original, dtype: int64

# %%
cleanData.head()
# Out:
#   Vernacular name - original                   Scientific Name  Taxon Rank  \
# 0  Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 1       New Zealand Fur Seal            Arctocephalus forsteri     species
# 2         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 3            Squirrel Glider             Petaurus norfolcensis     species
# 4         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
#
#     Kingdom    Phylum     Class        Family          Genus  Latitude  \
# 0  Animalia  Chordata  Mammalia  Macropodidae      Petrogale  -37.2149
# 1  Animalia  Chordata  Mammalia     Otariidae  Arctocephalus  -38.4152
# 2  Animalia  Chordata  Mammalia    Potoroidae       Potorous  -37.7909
# 3  Animalia  Chordata  Mammalia    Petauridae       Petaurus  -36.6901
# 4  Animalia  Chordata  Mammalia    Potoroidae       Potorous  -38.3900
#
#    Longitude Country - parsed State - parsed    Year  Individual count
# ...

# %%
cleanData['Year']=cleanData['Year'].astype(int)
# Out:
# /Users/root1/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cleanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8590 entries, 0 to 8589
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Vernacular name - original  8590 non-null   object
#  1   Scientific Name             8590 non-null   object
#  2   Taxon Rank                  8590 non-null   object
#  3   Kingdom                     8590 non-null   object
#  4   Phylum                      8590 non-null   object
#  5   Class                       8590 non-null   object
#  6   Family                      8590 non-null   object
#  7   Genus                       8590 non-null   object
#  8   Latitude                    8590 non-null   float64
#  9   Longitude                   8590 non-null   float64
#  10  Country - parsed            8590 non-null   object
#  11  State - parsed              8590 non-null   object
#  12  Year                        8590 non-null   int64
# ...

# %%
cleanData=cleanData.sort_values(['Year','Scientific Name'],ascending=False)

# %%
cleanData.to_csv('CleanStates/NSW_Clean.csv', sep=',', encoding='utf-8', index = False)

# %%
cleanData.groupby('Vernacular name - original').count()
# Out:
#                             Scientific Name  Taxon Rank  Kingdom  Phylum  \
# Vernacular name - original
# Australasian Fur Seal                     8           8        8       8
# Brush-tailed Rock Wallaby                24          24       24      24
# Brush-tailed Rock-wallaby               144         144      144     144
# Common Dunnart                          126         126      126     126
# Humpback Whale                          480         480      480     480
# Humpback whale                            4           4        4       4
# Long-nosed Potoroo                     1033        1033     1033    1033
# New Holland Mouse                       512         512      512     512
# New Zealand Fur Seal                     36          36       36      36
# Southern Right Whale                   5604        5604     5604    5604
# Southern right whale                      4           4        4       4
# ...

# %%
cleanData['Vernacular name - original'].value_counts()
# Out:
# Southern Right Whale         5604
# Long-nosed Potoroo           1033
# Squirrel Glider               606
# New Holland Mouse             512
# Humpback Whale                480
# Brush-tailed Rock-wallaby     144
# Common Dunnart                126
# New Zealand Fur Seal           36
# Brush-tailed Rock Wallaby      24
# Australasian Fur Seal           8
# long-eared bat                  8
# Humpback whale                  4
# Southern right whale            4
# humpback whale                  1
# Name: Vernacular name - original, dtype: int64

# %%
process("VIC","VIC_Clean")
process("TAS","TAS_Clean")
# process("QLD","QLD_Clean")
process("WA","WA_Clean")
# process("SA","SA_Clean")
process("ACT","ACT_Clean")
process("NT","NT_Clean")
# process("NSW","NSW_Clean")
# Out:
# VIC(9525, 57)
# TAS(35103, 57)
# WA(4197, 57)
# ACT(31, 57)
# NT(4955, 57)

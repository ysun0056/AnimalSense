# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("States/VIC.csv")
data.shape
# Out:
# (9525, 57)

# %%
#filter year > 1960
data=data[data.Year>=1960]
data.shape
#Drop un-wanted rows:
data=data[['Vernacular name - original','Scientific Name','Taxon Rank','Kingdom','Phylum','Class',
              'Family','Genus','Latitude','Longitude','Country - parsed','State - parsed','Year']]
data.shape
data.dropna(inplace=True)
data.shape
# Out:
# (9224, 13)

# %%
data.isnull().sum()
# Out:
# Vernacular name - original    0
# Scientific Name               0
# Taxon Rank                    0
# Kingdom                       0
# Phylum                        0
# Class                         0
# Family                        0
# Genus                         0
# Latitude                      0
# Longitude                     0
# Country - parsed              0
# State - parsed                0
# Year                          0
# dtype: int64

# %%
data.dropna(inplace=True)
data.shape
# Out:
# (9224, 13)

# %%
data.isnull().sum()
# Out:
# Vernacular name - original    0
# Scientific Name               0
# Taxon Rank                    0
# Kingdom                       0
# Phylum                        0
# Class                         0
# Family                        0
# Genus                         0
# Latitude                      0
# Longitude                     0
# Country - parsed              0
# State - parsed                0
# Year                          0
# dtype: int64

# %%
data.Year = data.Year.astype(int)
data.head()
# Out:
#   Vernacular name - original                   Scientific Name  Taxon Rank  \
# 0         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 1  Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 2       New Zealand Fur Seal            Arctocephalus forsteri     species
# 3         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 4            Squirrel Glider             Petaurus norfolcensis     species
#
#     Kingdom    Phylum     Class        Family          Genus  Latitude  \
# 0  Animalia  Chordata  Mammalia    Potoroidae       Potorous  -38.3900
# 1  Animalia  Chordata  Mammalia  Macropodidae      Petrogale  -37.2149
# 2  Animalia  Chordata  Mammalia     Otariidae  Arctocephalus  -38.4152
# 3  Animalia  Chordata  Mammalia    Potoroidae       Potorous  -37.7909
# 4  Animalia  Chordata  Mammalia    Petauridae       Petaurus  -36.6901
#
#    Longitude Country - parsed State - parsed  Year
# ...

# %%
# data['Count'] = data.groupby('Scientific Name').count()


# Drop duplicates

# data.drop_duplicates(subset ="Vernacular name - original", keep = "first", inplace = True) 
# data
new=data
new['Total_Count']=data.groupby('Scientific Name')['Scientific Name'].transform('count')

# %%
new
# Out:
#      Vernacular name - original                   Scientific Name  Taxon Rank  \
# 0            Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 1     Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 2          New Zealand Fur Seal            Arctocephalus forsteri     species
# 3            Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 4               Squirrel Glider             Petaurus norfolcensis     species
# ...                         ...                               ...         ...
# 9520       Southern Right Whale               Eubalaena australis     species
# 9521       Southern Right Whale               Eubalaena australis     species
# 9522          New Holland Mouse         Pseudomys novaehollandiae     species
# 9523       Southern Right Whale               Eubalaena australis     species
# 9524       Southern Right Whale               Eubalaena australis     species
#
# ...

# %%
data[(data.Year <=1970) ]
# Out:
#      Vernacular name - original                   Scientific Name  Taxon Rank  \
# 8     Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 35    Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 66              Squirrel Glider             Petaurus norfolcensis     species
# 68    Brush-tailed Rock-wallaby             Petrogale penicillata     species
# 132   Brush-tailed Rock Wallaby             Petrogale penicillata     species
# ...                         ...                               ...         ...
# 8665             Common Dunnart         Sminthopsis murina murina  subspecies
# 8710             Common Dunnart         Sminthopsis murina murina  subspecies
# 9125         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 9246         Long-nosed Potoroo  Potorous tridactylus tridactylus  subspecies
# 9324       Southern Right Whale               Eubalaena australis     species
#
# ...

# %%
data.Year.plot.hist(bins=15, alpha=1)

# %%
# !pip install plotly

# %%
import plotly.express as px
fig = px.scatter_geo(data, locations="", color="continent",
                     hover_name="country", size="pop",
                     projection="natural earth")
fig.show()

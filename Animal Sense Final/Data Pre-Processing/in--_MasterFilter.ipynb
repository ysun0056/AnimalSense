# %%
import pandas as pa
import numpy as np

# %%
masterData=pa.read_csv("Final/MasterData.csv")
masterData.shape
# Out:
# (188196, 13)

# %%
masterData.head()
# Out:
#   Vernacular name - original         Scientific Name  Taxon Rank   Kingdom  \
# 0         Long-nosed Potoroo    Potorous tridactylus  subspecies  Animalia
# 1  Brush-tailed Rock Wallaby   Petrogale penicillata     species  Animalia
# 2       New Zealand Fur Seal  Arctocephalus forsteri     species  Animalia
# 3         Long-nosed Potoroo    Potorous tridactylus  subspecies  Animalia
# 4            Squirrel Glider   Petaurus norfolcensis     species  Animalia
#
#      Phylum     Class        Family          Genus  Latitude  Longitude  \
# 0  Chordata  Mammalia    Potoroidae       Potorous  -38.3900   142.8430
# 1  Chordata  Mammalia  Macropodidae      Petrogale  -37.2149   142.2676
# 2  Chordata  Mammalia     Otariidae  Arctocephalus  -38.4152   142.0013
# 3  Chordata  Mammalia    Potoroidae       Potorous  -37.7909   148.7531
# 4  Chordata  Mammalia    Petauridae       Petaurus  -36.6901   144.8263
#
#   Country - parsed State - parsed    Year
# ...

# %%
#Unique Scientific Names:
masterData['Vernacular name - original'].value_counts()
# Out:
# Greater Bilby                      27353
# Tasmanian Devil                    25559
# Eastern Curlew                     18241
# Southern Elephant Seal              9399
# Southern Right Whale                9344
#                                    ...
# Laced Fritillary                       4
# Rufous-bellied Pademelon               3
# Pig-footed Bandicoot                   3
# Short-tailed Hopping Mouse             2
# star finch (eastern subspecies)        1
# Name: Vernacular name - original, Length: 152, dtype: int64

# %%
#Check Nulls :
masterData['Vernacular name - original'].value_counts()
# Out:
# Greater Bilby                      27353
# Tasmanian Devil                    25559
# Eastern Curlew                     18241
# Southern Elephant Seal              9399
# Southern Right Whale                9344
#                                    ...
# Laced Fritillary                       4
# Rufous-bellied Pademelon               3
# Pig-footed Bandicoot                   3
# Short-tailed Hopping Mouse             2
# star finch (eastern subspecies)        1
# Name: Vernacular name - original, Length: 152, dtype: int64

# %%
#change DataType Float to int:
masterData.dropna(inplace=True)
masterData.Year=masterData.Year.astype(int)
masterData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173658 entries, 0 to 188195
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Vernacular name - original  173658 non-null  object
#  1   Scientific Name             173658 non-null  object
#  2   Taxon Rank                  173658 non-null  object
#  3   Kingdom                     173658 non-null  object
#  4   Phylum                      173658 non-null  object
#  5   Class                       173658 non-null  object
#  6   Family                      173658 non-null  object
#  7   Genus                       173658 non-null  object
#  8   Latitude                    173658 non-null  float64
#  9   Longitude                   173658 non-null  float64
#  10  Country - parsed            173658 non-null  object
#  11  State - parsed              173658 non-null  object
# ...

# %% [markdown]
# ## Time-series distribution:

# %%
masterData.Year.hist()

# %%
masterData=masterData[masterData.Year>=1960]
masterData.shape
masterData.Year.hist()

# %%
masterData['Vernacular name - original'].value_counts()
# Out:
# Greater Bilby                               27164
# Tasmanian Devil                             25214
# Eastern Curlew                              14098
# Southern Elephant Seal                       9380
# Southern Right Whale                         9272
#                                             ...
# Southern Hairy-nosed Wombat                     4
# Pale Field-rat                                  4
# Short-tailed Hopping Mouse                      2
# crimson finch (white-bellied subspecies)        2
# Rufous-bellied Pademelon                        2
# Name: Vernacular name - original, Length: 145, dtype: int64

# %%
masterData.isnull().sum()
# Out:
# Vernacular name - original    0
# Scientific Name               0
# Taxon Rank                    0
# Kingdom                       0
# Phylum                        0
# Class                         0
# Family                        0
# Genus                         0
# Latitude                      0
# Longitude                     0
# Country - parsed              0
# State - parsed                0
# Year                          0
# dtype: int64

# %%
# masterData.to_csv('Final/MasterData_V4csv', sep=',', encoding='utf-8', index = False)

# %%
masterData.shape
# Out:
# (172046, 13)

# %%
masterData[(masterData.duplicated(keep='first'))==True]
# Out:
#        Vernacular name - original            Scientific Name  Taxon Rank  \
# 29             Long-nosed Potoroo       Potorous tridactylus  subspecies
# 54             Long-nosed Potoroo       Potorous tridactylus  subspecies
# 71             Long-nosed Potoroo       Potorous tridactylus  subspecies
# 72             Long-nosed Potoroo       Potorous tridactylus  subspecies
# 75                 Common Dunnart  Sminthopsis murina murina  subspecies
# ...                           ...                        ...         ...
# 188181               Plains Mouse        Pseudomys australis     species
# 188184   Southern Brown Bandicoot  Isoodon obesulus obesulus  subspecies
# 188186   Yellow-footed Antechinus        Antechinus flavipes     species
# 188190          Burrowing Bettong          Bettongia lesueur     species
# 188192               Plains Mouse        Pseudomys australis     species
#
#          Kingdom    Phylum     Class       Family        Genus  Latitude  \
# ...

# %%
len(masterData)-len(masterData.drop_duplicates())
# Out:
# 84276

# %%
srwhale=masterData[(masterData['Vernacular name - original']=="Southern Right Whale") &
                  (masterData.Year==2015)]
srwhale
# Out:
#        Vernacular name - original      Scientific Name Taxon Rank   Kingdom  \
# 625          Southern Right Whale  Eubalaena australis    species  Animalia
# 1382         Southern Right Whale  Eubalaena australis    species  Animalia
# 1406         Southern Right Whale  Eubalaena australis    species  Animalia
# 1431         Southern Right Whale  Eubalaena australis    species  Animalia
# 1766         Southern Right Whale  Eubalaena australis    species  Animalia
# ...                           ...                  ...        ...       ...
# 87344        Southern Right Whale  Eubalaena australis    species  Animalia
# 87463        Southern Right Whale  Eubalaena australis    species  Animalia
# 87645        Southern Right Whale  Eubalaena australis    species  Animalia
# 87816        Southern Right Whale  Eubalaena australis    species  Animalia
# 152218       Southern Right Whale  Eubalaena australis    species  Animalia
#
# ...

# %%
srwhale.drop_duplicates(inplace=True,keep="first")
srwhale.sort_values()
# Out:
# /Users/root1/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Vernacular name - original      Scientific Name Taxon Rank   Kingdom  \
# 625          Southern Right Whale  Eubalaena australis    species  Animalia
# 1382         Southern Right Whale  Eubalaena australis    species  Animalia
# 1431         Southern Right Whale  Eubalaena australis    species  Animalia
# 5278         Southern Right Whale  Eubalaena australis    species  Animalia
# 5470         Southern Right Whale  Eubalaena australis    species  Animalia
# 5804         Southern Right Whale  Eubalaena australis    species  Animalia
# 5999         Southern Right Whale  Eubalaena australis    species  Animalia
# ...

# %%
len(srwhale)-len(srwhale.drop_duplicates())
# Out:
# 0

# %%
masterData.shape
# Out:
# (172046, 13)

# %%
# # mastderDropDup=masterData.drop_duplicates(keep='first')
# mastderDropDup.shape
# mastderDropDup.to_csv('Final/masterData_V5.csv', sep=',', encoding='utf-8', index = False)

# %%
#master Data drop Duplicate:
masterData=masterData.drop_duplicates(keep='first')
masterData.shape
# Out:
# (87770, 13)

# %%
masterData.sort_values(by="Year").drop_duplicates(subset=["Vernacular name - original"], keep="last")
# Out:
#        Vernacular name - original                       Scientific Name  \
# 148328   Rufous-bellied Pademelon                Thylogale billardierii
# 124632    White-footed Rabbit Rat                     Conilurus albipes
# 82819                    Nabarlek           Petrogale concinna concinna
# 134545             Pale Field-rat                        Rattus tunneyi
# 36620            Laced Fritillary         Argynnis hyperbius inconstans
# ...                           ...                                   ...
# 79289             Fawn Antechinus                     Antechinus bellus
# 37828              Eastern Curlew  Numenius (Numenius) madagascariensis
# 101067            Tasmanian Devil                  Sarcophilus harrisii
# 5                 Squirrel Glider                 Petaurus norfolcensis
# 84347                      Quokka                    Setonix brachyurus
#
#         Taxon Rank   Kingdom      Phylum     Class        Family        Genus  \
# ...

# %%
masterData.groupby(['Vernacular name - original','Year']).sum()
# Out:
#                                                   Latitude    Longitude
# Vernacular name - original               Year
# Agile Antechinus                         2004   -38.000700   140.964130
#                                          2006   -37.996300   140.965890
#                                          2018   -75.954870   281.928540
# Armoured Frog                            1971   -16.500000   145.300000
#                                          1976   -32.200000   290.700000
# ...                                                    ...          ...
# Yellow-footed Rock Wallaby               2017  -791.470664  3461.323904
#                                          2018 -1095.698966  4852.778704
#                                          2019  -462.842567  2083.179286
# crimson finch (white-bellied subspecies) 1980   -14.900000   141.600000
#                                          2009   -15.200000   144.400000
#
# [3391 rows x 2 columns]

# %%
new=masterData
new['Total_Count']=new.groupby(['Scientific Name','Year'])['Scientific Name'].transform('count')

# %%
new
# Out:
#        Vernacular name - original         Scientific Name  Taxon Rank  \
# 0              Long-nosed Potoroo    Potorous tridactylus  subspecies
# 1       Brush-tailed Rock Wallaby   Petrogale penicillata     species
# 2            New Zealand Fur Seal  Arctocephalus forsteri     species
# 3              Long-nosed Potoroo    Potorous tridactylus  subspecies
# 4                 Squirrel Glider   Petaurus norfolcensis     species
# ...                           ...                     ...         ...
# 188189              Greater Bilby        Macrotis lagotis     species
# 188191              Greater Bilby        Macrotis lagotis     species
# 188193              Greater Bilby        Macrotis lagotis     species
# 188194          Burrowing Bettong       Bettongia lesueur     species
# 188195              Greater Bilby        Macrotis lagotis     species
#
#          Kingdom    Phylum     Class         Family          Genus  Latitude  \
# ...

# %%
#per Year Count
new.to_csv('Final/MasterPerYear.csv', sep=',', encoding='utf-8', index = False)
